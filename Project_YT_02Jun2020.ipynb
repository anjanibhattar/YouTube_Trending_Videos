# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\anjan\OneDrive\Desktop\Project_YT\USvideos.csv')

# %%
data.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
data.shape
# Out:
# (40949, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
# video_id                  40949 non-null object
# trending_date             40949 non-null object
# title                     40949 non-null object
# channel_title             40949 non-null object
# category_id               40949 non-null int64
# publish_time              40949 non-null object
# tags                      40949 non-null object
# views                     40949 non-null int64
# likes                     40949 non-null int64
# dislikes                  40949 non-null int64
# comment_count             40949 non-null int64
# thumbnail_link            40949 non-null object
# comments_disabled         40949 non-null bool
# ratings_disabled          40949 non-null bool
# video_error_or_removed    40949 non-null bool
# description               40379 non-null object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %%
data.head(5)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
data.description.isna().sum()
# Out:
# 570

# %%
data[data.description.apply(lambda x:pd.isna(x))].head(5)
# Out:
#         video_id trending_date  \
# 42   NZFhMSgbKKM      17.14.11
# 47   sbcbvuitiTc      17.14.11
# 175  4d07RXYLsJE      17.14.11
# 267  NZFhMSgbKKM      17.15.11
# 312  sbcbvuitiTc      17.15.11
#
#                                                  title  \
# 42   Dennis Smith Jr. and LeBron James go back and ...
# 47   Stephon Marbury and Jimmer Fredette fight in C...
# 175                Sphaera - demonstrating interaction
# 267  Dennis Smith Jr. and LeBron James go back and ...
# 312  Stephon Marbury and Jimmer Fredette fight in C...
#
#                 channel_title  category_id              publish_time  \
# 42               Ben Rohrbach           17  2017-11-13T15:11:00.000Z
# 47   NBA Highlights · YouTube           17  2017-11-10T18:23:05.000Z
# 175              Jenny Hanell           28  2017-11-04T20:48:16.000Z
# 267              Ben Rohrbach           17  2017-11-13T15:11:00.000Z
# 312  NBA Highlights · YouTube           17  2017-11-10T18:23:05.000Z
#
# ...

# %%
df1 = data

# %%
df1.description.isna().sum()
# Out:
# 570

# %%
df1.description = df1.description.fillna(value = 'NA')

# %%
df1.description.isna().sum()
# Out:
# 0

# %%
df1.description.value_counts()
# Out:
# NA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
# ...

# %%
df1.publish_time
# Out:
# 0        2017-11-13T17:13:01.000Z
# 1        2017-11-13T07:30:00.000Z
# 2        2017-11-12T19:05:24.000Z
# 3        2017-11-13T11:00:04.000Z
# 4        2017-11-12T18:01:41.000Z
# 5        2017-11-13T19:07:23.000Z
# 6        2017-11-12T05:37:17.000Z
# 7        2017-11-12T21:50:37.000Z
# 8        2017-11-13T14:00:23.000Z
# 9        2017-11-13T13:45:16.000Z
# 10       2017-11-13T02:05:26.000Z
# 11       2017-11-13T03:00:00.000Z
# 12       2017-11-13T17:00:00.000Z
# 13       2017-11-12T14:00:00.000Z
# 14       2017-11-12T18:30:01.000Z
# 15       2017-11-13T20:09:58.000Z
# 16       2017-11-12T17:00:05.000Z
# 17       2017-11-13T16:00:07.000Z
# 18       2017-11-13T15:30:17.000Z
# 19       2017-11-12T22:00:01.000Z
# 20       2017-11-13T14:00:03.000Z
# 21       2017-11-12T15:00:01.000Z
# 22       2017-11-13T16:00:03.000Z
# 23       2017-11-12T16:00:01.000Z
# 24       2017-11-13T14:44:24.000Z
# 25       2017-11-12T14:00:04.000Z
# 26       2017-11-13T12:13:36.000Z
# ...

# %%
df2 = pd.to_datetime(df1['publish_time']).dt.date

# %%
df2.head(15)
# Out:
# 0     2017-11-13
# 1     2017-11-13
# 2     2017-11-12
# 3     2017-11-13
# 4     2017-11-12
# 5     2017-11-13
# 6     2017-11-12
# 7     2017-11-12
# 8     2017-11-13
# 9     2017-11-13
# 10    2017-11-13
# 11    2017-11-13
# 12    2017-11-13
# 13    2017-11-12
# 14    2017-11-12
# Name: publish_time, dtype: object

# %%
df3 = pd.to_datetime(df1['publish_time']).dt.time

# %%
df3.head(15)
# Out:
# 0     17:13:01
# 1     07:30:00
# 2     19:05:24
# 3     11:00:04
# 4     18:01:41
# 5     19:07:23
# 6     05:37:17
# 7     21:50:37
# 8     14:00:23
# 9     13:45:16
# 10    02:05:26
# 11    03:00:00
# 12    17:00:00
# 13    14:00:00
# 14    18:30:01
# Name: publish_time, dtype: object

# %%
df1['publish_date'] = pd.to_datetime(df1['publish_time']).dt.date

# %%
df1['publish_time2'] = pd.to_datetime(df1['publish_time']).dt.time

# %%
df1.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
from datetime import date

# %%
import calendar

# %%
import datetime

# %%
df2=df1

# %%
df2['publishing_day'] = df2['publish_time'].apply(lambda x: datetime.datetime.strptime(x[:10], "%Y-%m-%d").date().strftime('%a'))

# %%
# Read more about strftime function here
# https://www.programiz.com/python-programming/datetime/strftime

# %%
df2.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
dtags = df2["tags"]

# %%
dtags.head(2)
# Out:
# 0                                      SHANtell martin
# 1    last week tonight trump presidency|"last week ...
# Name: tags, dtype: object

# %%
ar = dtags.values

# %%
ar.str.count('|')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-863c409abde0> in <module>
# ----> 1 ar.str.count('|')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'str'

# %%
import re

# %%
import fnmatch

# %%
thumbnail = fnmatch.filter(df2["thumbnail_link"], '*/default.jpg')

# %%
thumbnail
# Out:
# ['https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg',
#  'https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg',
#  'https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg',
#  'https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg',
#  'https://i.ytimg.com/vi/d380meD0W0M/default.jpg',
#  'https://i.ytimg.com/vi/gHZ1Qz0KiKM/default.jpg',
#  'https://i.ytimg.com/vi/39idVpFF7NQ/default.jpg',
#  'https://i.ytimg.com/vi/nc99ccSXST0/default.jpg',
#  'https://i.ytimg.com/vi/jr9QtXwC9vc/default.jpg',
#  'https://i.ytimg.com/vi/TUmyygCMMGA/default.jpg',
#  'https://i.ytimg.com/vi/9wRQljFNDW8/default.jpg',
#  'https://i.ytimg.com/vi/VifQlJit6A0/default.jpg',
#  'https://i.ytimg.com/vi/5E4ZBSInqUU/default.jpg',
#  'https://i.ytimg.com/vi/GgVmn66oK_A/default.jpg',
#  'https://i.ytimg.com/vi/TaTleo4cOs8/default.jpg',
#  'https://i.ytimg.com/vi/kgaO45SyaO4/default.jpg',
#  'https://i.ytimg.com/vi/ZAQs-ctOqXQ/default.jpg',
#  'https://i.ytimg.com/vi/YVfyYrEmzgM/default.jpg',
# ...

# %%
len(thumbnail)
# Out:
# 40937

# %%
tb = fnmatch.filter(df2["thumbnail_link"], '!*/default.jpg')

# %%
len(tb)
# Out:
# 0

# %%
tb = df2[~df2['thumbnail_link'].isin(thumbnail)]

# %%
len(tb)
# Out:
# 12

# %%
tb
# Out:
#           video_id trending_date  \
# 11500  1JNxKJnPDAs      18.12.01
# 11742  1JNxKJnPDAs      18.13.01
# 11961  1JNxKJnPDAs      18.14.01
# 12191  1JNxKJnPDAs      18.15.01
# 18283  d-73-Cr0tQs      18.15.02
# 18513  d-73-Cr0tQs      18.16.02
# 18741  d-73-Cr0tQs      18.17.02
# 18950  d-73-Cr0tQs      18.18.02
# 28550  9TUBf6l7FBg      18.14.04
# 28751  9TUBf6l7FBg      18.15.04
# 28955  9TUBf6l7FBg      18.16.04
# 33553  ogfYd705cRs      18.09.05
#
#                                                 title  \
# 11500                     Southwest Florida Eagle Cam
# 11742                     Southwest Florida Eagle Cam
# 11961                     Southwest Florida Eagle Cam
# 12191                     Southwest Florida Eagle Cam
# 18283  LIVE 🔴 - PyeongChang 2018 Olympic Winter Games
# 18513  LIVE 🔴 - PyeongChang 2018 Olympic Winter Games
# 18741  LIVE 🔴 - PyeongChang 2018 Olympic Winter Games
# 18950  LIVE 🔴 - PyeongChang 2018 Olympic Winter Games
# ...

# %%
tb['thumbnail_link']
# Out:
# 11500    https://i.ytimg.com/vi/1JNxKJnPDAs/default_liv...
# 11742    https://i.ytimg.com/vi/1JNxKJnPDAs/default_liv...
# 11961    https://i.ytimg.com/vi/1JNxKJnPDAs/default_liv...
# 12191    https://i.ytimg.com/vi/1JNxKJnPDAs/default_liv...
# 18283    https://i.ytimg.com/vi/d-73-Cr0tQs/default_liv...
# 18513    https://i.ytimg.com/vi/d-73-Cr0tQs/default_liv...
# 18741    https://i.ytimg.com/vi/d-73-Cr0tQs/default_liv...
# 18950    https://i.ytimg.com/vi/d-73-Cr0tQs/default_liv...
# 28550    https://i.ytimg.com/vi/9TUBf6l7FBg/default_liv...
# 28751    https://i.ytimg.com/vi/9TUBf6l7FBg/default_liv...
# 28955    https://i.ytimg.com/vi/9TUBf6l7FBg/default_liv...
# 33553    https://i.ytimg.com/vi/ogfYd705cRs/default_liv...
# Name: thumbnail_link, dtype: object

# %%
df2[df2['channel_title'] == 'Coachella']
# Out:
#           video_id trending_date                          title channel_title  \
# 28550  9TUBf6l7FBg      18.14.04  Coachella 2018 LIVE Channel 1     Coachella
# 28751  9TUBf6l7FBg      18.15.04  Coachella 2018 LIVE Channel 1     Coachella
# 28955  9TUBf6l7FBg      18.16.04  Coachella 2018 LIVE Channel 1     Coachella
#
#        category_id              publish_time    tags     views  likes  \
# 28550           10  2018-04-05T06:48:28.000Z  [none]   3598220      0
# 28751           10  2018-04-05T06:48:28.000Z  [none]  11137071      0
# 28955           10  2018-04-05T06:48:28.000Z  [none]  24004779      0
#
#        dislikes  comment_count  \
# 28550         0              0
# 28751         0              2
# 28955         0              3
#
#                                           thumbnail_link  comments_disabled  \
# 28550  https://i.ytimg.com/vi/9TUBf6l7FBg/default_liv...              False
# 28751  https://i.ytimg.com/vi/9TUBf6l7FBg/default_liv...              False
# ...

# %%
import json

# %%
with open(r"C:\Users\anjan\OneDrive\Desktop\Project_YT\US_category_id.json") as f:
    categories = json.load(f)["items"]
cat_dict = {}
for cat in categories:
    cat_dict[int(cat["id"])] = cat["snippet"]["title"]
df2["category_name"] = df2["category_id"].map(cat_dict)

# %%
df2.head(3)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
#
#                                                title    channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE     CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...  LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...     Rudy Mancuso
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
#
#    dislikes  comment_count                                  thumbnail_link  \
# ...
